# %%
import pandas as pd

# %%
train_df = pd.read.csv('/home/fernando/Desktop/workspace/Credit-Score-Classification/data/train.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_df = pd.read.csv('/home/fernando/Desktop/workspace/Credit-Score-Classification/data/train.csv')
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df_test =
